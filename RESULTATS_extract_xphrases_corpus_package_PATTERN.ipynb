# %% [markdown]
# #### Résultat n°1 : couples qui matchent obtenus à partir de l'algorithme "chunking"

# %%
df_resultat_0
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_ad6e372e_e9a5_11e8_8021_f85971853fcc" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >str_result</th>
#         <th class="col_heading level0 col1" >RESULTAT_FINAL</th>
#         <th class="col_heading level0 col2" >URLS</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_ad6e372e_e9a5_11e8_8021_f85971853fcclevel0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_ad6e372e_e9a5_11e8_8021_f85971853fccrow0_col0" class="data row0 col0" >chateau angelus</td>
#         <td id="T_ad6e372e_e9a5_11e8_8021_f85971853fccrow0_col1" class="data row0 col1" >['chateau-angelus-2014-14351' 'wac' 'chateau angelus 2014']</td>
# ...

# %% [markdown]
# #### Résultat n°2 : grâce au découpage "vérité", nombres de couples qui matchent par "set" d'entités et année

# %%
df_resultat_matching_wines_using_vins_decoupes_entirely_agg[['nb_couples_matched']]
# Out:
#                                                         nb_couples_matched
# str_result                                        year
# batard-montrachet grand cru|olivier leflaive      2009  1
#                                                   2013  1
#                                                   2014  1
#                                                   2015  1
#                                                   2016  1
# blanc|chateau brown                               2015  1
# blanc|chateau pape clement                        2016  1
# blanc|clos canarelli                              2016  1
# blanc|domaine chevalier                           2014  1
# champagne ruinart|blanc blancs                    NA    1
# chardonnay|cloudy bay                             2014  1
#                                                   2015  1
# chardonnay|penfolds|koonunga hill                 2016  1
# chateau angelus                                   2014  1
# ...

# %% [markdown]
# #### Résultat n°3 : dataset "vérité" de couples de vins qui matchent

# %%
df_resultat_matching_wines_using_vins_decoupes_entirely
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_bac28d6c_e9a5_11e8_8021_f85971853fcc" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >str_result</th>
#         <th class="col_heading level0 col1" >RESULTAT_FINAL</th>
#         <th class="col_heading level0 col2" >URLS</th>
#         <th class="col_heading level0 col3" >year</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_bac28d6c_e9a5_11e8_8021_f85971853fcclevel0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_bac28d6c_e9a5_11e8_8021_f85971853fccrow0_col0" class="data row0 col0" >batard-montrachet grand cru|olivier leflaive</td>
#         <td id="T_bac28d6c_e9a5_11e8_8021_f85971853fccrow0_col1" class="data row0 col1" >['olivier-leflaive-batard-montrachet-grand-cru-2009' 'mll'
#  'olivier leflaive batard-montrachet grand cru 2009']</td>
# ...
